-- %%
%sql
CREATE OR REPLACE TABLE sts_prd.`01_ipd_thering`.s_billing_master_ga_ipd
USING DELTA
AS
WITH base AS (
  -- =========================
  -- Everest (direct_sales_everest)
  -- =========================
  SELECT
      CAST(BillingSourceSystem AS STRING)                               AS `Billing Source System`,
      CAST(SourceSystemId AS STRING)                                     AS `Source System Id`,
      CAST(MaterialId AS STRING)                                         AS `Material Id`,
      CAST(MaterialKey AS STRING)                                        AS `Material Key`,
      CAST(BillMasterKey AS STRING)                                      AS `Bill Master Key`,
      CAST(ErpCustomerKey AS STRING)                                     AS `Erp Customer Key`,
      CAST(DistributorKey AS STRING)                                     AS `Distributor Key`,
      CAST(CustomerMasterSalesKey AS STRING)                             AS `Customer Master Sales Key`,
      CAST(AgreementKey AS STRING)                                       AS `Agreement Key`,
      CAST(InvoiceDate AS DATE)                                          AS `Invoice Date`,
      CAST(DocumentId AS STRING)                                         AS `Document Id`,
      CAST(DocumentIdItem AS STRING)                                     AS `Document Id Item`,
      CAST(InvoiceNumber AS STRING)                                      AS `Invoice Number`,
      CAST(InvoiceLineItem AS STRING)                                    AS `Invoice Line Item`,
      CAST(BillingType AS STRING)                                        AS `Billing Type`,
      CAST(BillingTypeDescription AS STRING)                             AS `Billing Type Description`,
      CAST(SalesOrder AS STRING)                                         AS `Sales Order`,
      CAST(SalesOrderItem AS STRING)                                     AS `Sales Order Item`,
      CAST(SalesItemCategory AS STRING)                                  AS `Sales Item Category`,
      CAST(BaseUom AS STRING)                                            AS `Base Uom`,
      CAST(SalesUom AS STRING)                                           AS `Sales Uom`,
      CAST(BillingQuantity AS DECIMAL(15,3))                             AS `Billing Quantity`,
      CAST(BillQtyInEa AS DECIMAL(23,4))                                 AS `Billing Quantity in EA`,
      CAST(InvoiceQuantity AS DECIMAL(13,3))                             AS `Invoice Quantity`,
      CAST(LocalCurrency AS STRING)                                      AS `Local Currency`,
      CAST(ActualNetRevenue AS DECIMAL(25,2))                            AS `Actual Net Revenue`,
      CAST(SalesOrgId AS STRING)                                         AS `Sales Org Id`,
      CAST(SalesOrgDescription AS STRING)                                AS `Sales Org Description`,
      CAST(DistributionChannel AS STRING)                                AS `Distribution Channel`,
      CAST(DistributionChannelDescription AS STRING)                     AS `Distribution Channel Description`,
      CAST(Division AS STRING)                                           AS Division,
      CAST(DivisionDescription AS STRING)                                AS `Division Description`,
      CAST(ProfitCenterId AS STRING)                                     AS `Profit Center Id`,
      CAST(ProfitCenterDescription AS STRING)                            AS `Profit Center Description`,
      CAST(Plant AS STRING)                                              AS Plant,
      CAST(PlantDescription AS STRING)                                   AS `Plant Description`,
      CAST(GrossSales AS DECIMAL(13,2))                                  AS `Gross Sales`,
      CAST(GrossRevenue AS DECIMAL(23,2))                                AS `Gross Revenue`,
      CAST(DiscountedNetValue AS DECIMAL(13,2))                          AS `Discounted Net Value`,
      CAST(DiscountedNetValueAdjusted AS DECIMAL(13,2))                  AS `Discounted Net Value Adjusted`,
      CAST(ShippingHandlingFreightSurcharge AS DECIMAL(13,2))            AS `Shipping Handling Freight Surcharge`,
      CAST(Adjustments AS DECIMAL(13,2))                                 AS Adjustments,
      CAST(SalesTax AS DECIMAL(13,2))                                    AS `Sales Tax`,
      CAST(CustomerPoNumber AS STRING)                                   AS `Customer Po Number`,
      CAST(ConditionPricingUnit AS STRING)                               AS `Condition Pricing Unit`,
      CAST(PricingDate AS DATE)                                          AS `Pricing Date`,
      CAST(ProductHierarchy AS STRING)                                   AS `Product Hierarchy`,
      CAST(DirectSalesViewFlag AS STRING)                                AS `Direct Sales View Flag`,
      CAST(CustomerViewFlag AS STRING)                                   AS `Customer View Flag`,
      CAST(SalesFlag AS STRING)                                          AS `Sales Flag`,
      CAST('' AS STRING)                                                 AS `Unsettled Tracing Flag`,
      CAST('' AS STRING)                                                 AS `Recipient Id`,
      CAST('' AS STRING)                                                 AS `Recipient Role`,
      CAST('' AS STRING)                                                 AS `Sales Data Type`,
      CAST(Payer AS STRING)                                              AS Payer,
      CAST(SalesDocumentType AS STRING)                                  AS `Sales Document Type`,
      CAST(SalesDocumentTypeDescription AS STRING)                       AS `Sales Document Type Description`,
      CAST(RecordIndicator AS STRING)                                    AS `Record Indicator`,
      CAST(ContractAtTimeOfSale AS STRING)                               AS `Contract At Time Of Sale`,
      CAST(IndirectSellDate AS DATE)                                     AS `Indirect Sell Date`,
      CAST(TransactionType AS STRING)                                    AS `Transaction Type`,
      CAST(0 AS INT)                                                     AS `Sales Package Quantity`,
      CAST(LineCost AS DECIMAL(38,6))                                    AS `Line Cost`,
      CAST('' AS STRING)                                                 AS `Actual Gross Profit`,
      CAST(ShipToAccountNumber AS STRING)                                AS `Ship To Account Number`,
      CAST(BillToAccountNumber AS STRING)                                AS `Bill To Account Number`,
      CAST(SoldToAccountNumber AS STRING)                                AS `Sold To Account Number`,
      CAST(UnitSellingPrice AS DECIMAL(36,11))                           AS `Unit Selling Price`,
      CAST(RebateAccrual AS DECIMAL(15,2))                               AS `Rebate Accrual`,
      CAST(ActualRebateAmount AS DECIMAL(15,2))                          AS `Actual Rebate Amount`,
      CAST(GpoAtTimeOfSale AS STRING)                                    AS `Gpo At Time Of Sale`,
      CAST(0.0 AS DECIMAL(11,2))                                         AS `Brokerage Percentage`,
      CAST(TradeOrgAtTimeOfSale AS STRING)                               AS `Trade Org At Time Of Sale`,
      CAST(Country AS STRING)                                            AS Country,
      CAST(CountryListPrice AS DECIMAL(15,2))                            AS `Country List Price`,
      CAST(ListPrice AS DECIMAL(17,2))                                   AS `List Price`,
      CAST(DistributorBranchKey AS STRING)                               AS `Distributor Branch Key`,
      CAST(DistributorNumber AS STRING)                                  AS `Distributor Number`,
      CAST('' AS STRING)                                                 AS `Reason Code`,
      CAST('' AS STRING)                                                 AS `Reason Code Description`,
      CAST('' AS STRING)                                                 AS `Settlement Number`,
      CAST(NULL AS DATE)                                                 AS `Settlement Date`,
      CAST('' AS STRING)                                                 AS `Reference Number`,
      CAST('' AS STRING)                                                 AS `Rebate Period`,
      CAST('' AS STRING)                                                 AS `Trade Org No`,
      CAST(0.0 AS DECIMAL(15,3))                                         AS `Quantity`,
      CAST(0.0 AS DECIMAL(15,2))                                         AS `Settlement Amount`,
      CAST('' AS STRING)                                                 AS `Reference Item`,
      CAST('' AS STRING)                                                 AS `Settlement Status Item`,
      CAST('' AS STRING)                                                 AS `Debit Credit Indicator`,
      CAST('' AS STRING)                                                 AS `Header Settlement Status`,
      CAST(NULL AS DATE)                                                 AS `Billing Date`,
      CAST(0.0 AS DECIMAL(15,2))                                         AS `Dealer Submitted Cost`,
      CAST(0.0 AS DECIMAL(11,2))                                         AS `Net Price`,
      CAST(0 AS INT)                                                     AS `Numerator`,
      CAST(0 AS INT)                                                     AS `Denominator`,
      CAST(NULL AS DATE)                                                 AS `Last Settlement Date`,
      CAST(NULL AS DATE)                                                 AS `Tracings Approval Date`,
      CAST('' AS STRING)                                                 AS `Agreement Determined`,
      CAST('' AS STRING)                                                 AS `Deletion Indicator Header`,
      CAST('' AS STRING)                                                 AS `Deletion Indicator Item`,
      CAST('' AS STRING)                                                 AS `Translated Agreement`,
      CAST('' AS STRING)                                                 AS `Tolerance Indicator`,
      CAST('' AS STRING)                                                 AS `Rebate Payment Type`,
      CAST(NULL AS DATE)                                                 AS `Claim Item Batch Creation Date`,
      CAST('' AS STRING)                                                 AS `Period Close Indicator`,
      CAST(NULL AS DATE)                                                 AS `Created On Header`,
      CAST(NULL AS DATE)                                                 AS `Created On Item`,
      CAST('' AS STRING)                                                 AS `Condition Document Number`,
      CAST('' AS STRING)                                                 AS `Changed By Item`,
      CAST('' AS STRING)                                                 AS `Changed On Item`,
      CAST('' AS STRING)                                                 AS `Material Description Japanese`,
      CAST('' AS STRING)                                                 AS `Distributor End Customer No`,
      CAST('' AS STRING)                                                 AS `Territory Key`,
      CAST('' AS STRING)                                                 AS `Jde Material Category Key`,
      CAST(MaterialCostKey AS STRING)                                    AS `Material Cost Key`,
      CAST('' AS STRING)                                                 AS `Budget Key`,
      CAST(ShipToPo AS STRING)                                           AS `Ship To Po`,
      CAST(Year AS INT)                                                  AS Year,
      CAST(Month AS INT)                                                 AS Month,
      CAST(Wwb AS STRING)                                                AS Wwb,
      CAST(StrategyCenter AS STRING)                                     AS `Strategy Center`,
      CAST('' AS STRING)                                                 AS `Lot No`,
      CAST('' AS STRING)                                                 AS `Rebate Code`,
      CAST(BusinessPartnerArea AS STRING)                                AS `Business Partner Area`,
      CAST(AccountingDocument AS STRING)                                 AS `Accounting Document`,
      CAST(ReferenceDocument AS STRING)                                  AS `Reference Document`,
      CAST(CustomerMaterial AS STRING)                                   AS `Customer Material`,
      CAST(CustomerMaterialDescription AS STRING)                        AS `Customer Material Description`,
      CAST(Batch AS STRING)                                              AS Batch,
      CAST(RequestedDeliveryDate AS DATE)                                AS `Requested Delivery Date`,
      CAST(SalesOrderDate AS DATE)                                       AS `Sales Order Date`,
      CAST(cal.FirstDateOfMonth AS DATE)                                 AS `First Date Of Month`,
      CAST(dse.DateAdded AS TIMESTAMP)                                   AS `Date Added`
  FROM hub_prd.s_commops_ga.direct_sales_everest dse
  LEFT JOIN hub_prd.s_shared.calendar_periods_ga cal
    ON cal.CalendarDate = CAST(dse.InvoiceDate AS DATE)

  UNION ALL

  -- =========================
  -- JDE (direct_sales_jde)
  -- =========================
  SELECT
      CAST(BillingSourceSystem AS STRING)                                AS `Billing Source System`,
      CAST(SourceSystemId AS STRING)                                      AS `Source System Id`,
      CAST('' AS STRING)                                                  AS `Material Id`,
      CAST(MaterialKey AS STRING)                                         AS `Material Key`,
      CAST(BillMasterKey AS STRING)                                       AS `Bill Master Key`,
      CAST(ErpCustomerKey AS STRING)                                      AS `Erp Customer Key`,
      CAST(DistributorKey AS STRING)                                      AS `Distributor Key`,
      CAST('' AS STRING)                                                  AS `Customer Master Sales Key`,
      CAST('' AS STRING)                                                  AS `Agreement Key`,
      CAST(InvoiceDate AS DATE)                                           AS `Invoice Date`,
      CAST(DocumentId AS STRING)                                          AS `Document Id`,
      CAST(DocumentIdItem AS STRING)                                      AS `Document Id Item`,
      CAST(InvoiceNumber AS STRING)                                       AS `Invoice Number`,
      CAST(InvoiceLineItem AS STRING)                                     AS `Invoice Line Item`,
      CAST(BillingType AS STRING)                                         AS `Billing Type`,
      CAST(BillingTypeDescription AS STRING)                              AS `Billing Type Description`,
      CAST(SalesOrder AS STRING)                                          AS `Sales Order`,
      CAST(SalesOrderItem AS STRING)                                      AS `Sales Order Item`,
      CAST('' AS STRING)                                                  AS `Sales Item Category`,
      CAST(BaseUom AS STRING)                                             AS `Base Uom`,
      CAST(SalesUom AS STRING)                                            AS `Sales Uom`,
      CAST(BillingQuantity AS DECIMAL(15,3))                              AS `Billing Quantity`,
      CAST(BillQtyInEa AS DECIMAL(23,4))                                  AS `Billing Quantity in EA`,
      CAST(InvoiceQuantity AS DECIMAL(13,3))                              AS `Invoice Quantity`,
      CAST(LocalCurrency AS STRING)                                       AS `Local Currency`,
      CAST(ActualNetRevenue AS DECIMAL(25,2))                             AS `Actual Net Revenue`,
      CAST(SalesOrgId AS STRING)                                          AS `Sales Org Id`,
      CAST(SalesOrgDescription AS STRING)                                 AS `Sales Org Description`,
      CAST('' AS STRING)                                                  AS `Distribution Channel`,
      CAST('' AS STRING)                                                  AS `Distribution Channel Description`,
      CAST(Division AS STRING)                                            AS Division,
      CAST(DivisionDescription AS STRING)                                 AS `Division Description`,
      CAST(ProfitCenterId AS STRING)                                      AS `Profit Center Id`,
      CAST('' AS STRING)                                                  AS `Profit Center Description`,
      CAST(Plant AS STRING)                                               AS Plant,
      CAST(PlantDescription AS STRING)                                    AS `Plant Description`,
      CAST(0.0 AS DECIMAL(13,2))                                          AS `Gross Sales`,
      CAST(GrossRevenue AS DECIMAL(23,2))                                 AS `Gross Revenue`,
      CAST(0.0 AS DECIMAL(13,2))                                          AS `Discounted Net Value`,
      CAST(0.0 AS DECIMAL(13,2))                                          AS `Discounted Net Value Adjusted`,
      CAST(0.0 AS DECIMAL(13,2))                                          AS `Shipping Handling Freight Surcharge`,
      CAST(0.0 AS DECIMAL(13,2))                                          AS Adjustments,
      CAST(0.0 AS DECIMAL(13,2))                                          AS `Sales Tax`,
      CAST(CustomerPoNumber AS STRING)                                    AS `Customer Po Number`,
      CAST('' AS STRING)                                                  AS `Condition Pricing Unit`,
      CAST(NULL AS DATE)                                                  AS `Pricing Date`,
      CAST('' AS STRING)                                                  AS `Product Hierarchy`,
      CAST(DirectSalesViewFlag AS STRING)                                 AS `Direct Sales View Flag`,
      CAST(CustomerViewFlag AS STRING)                                    AS `Customer View Flag`,
      CAST(SalesFlag AS STRING)                                           AS `Sales Flag`,
      CAST('' AS STRING)                                                  AS `Unsettled Tracing Flag`,
      CAST('' AS STRING)                                                  AS `Recipient Id`,
      CAST('' AS STRING)                                                  AS `Recipient Role`,
      CAST('' AS STRING)                                                  AS `Sales Data Type`,
      CAST('' AS STRING)                                                  AS Payer,
      CAST(SalesDocumentType AS STRING)                                   AS `Sales Document Type`,
      CAST(SalesDocumentTypeDescription AS STRING)                        AS `Sales Document Type Description`,
      CAST(RecordIndicator AS STRING)                                     AS `Record Indicator`,
      CAST('' AS STRING)                                                  AS `Contract At Time Of Sale`,
      CAST(IndirectSellDate AS DATE)                                      AS `Indirect Sell Date`,
      CAST(TransactionType AS STRING)                                     AS `Transaction Type`,
      CAST(0 AS INT)                                                      AS `Sales Package Quantity`,
      CAST(LineCost AS DECIMAL(38,6))                                     AS `Line Cost`,
      CAST('' AS STRING)                                                  AS `Actual Gross Profit`,
      CAST(ShipToAccountNumber AS STRING)                                 AS `Ship To Account Number`,
      CAST(BillToAccountNumber AS STRING)                                 AS `Bill To Account Number`,
      CAST(SoldToAccountNumber AS STRING)                                 AS `Sold To Account Number`,
      CAST(UnitSellingPrice AS DECIMAL(36,11))                            AS `Unit Selling Price`,
      CAST(0.0 AS DECIMAL(15,2))                                          AS `Rebate Accrual`,
      CAST(0.0 AS DECIMAL(15,2))                                          AS `Actual Rebate Amount`,
      CAST('' AS STRING)                                                  AS `Gpo At Time Of Sale`,
      CAST(0.0 AS DECIMAL(11,2))                                          AS `Brokerage Percentage`,
      CAST('' AS STRING)                                                  AS `Trade Org At Time Of Sale`,
      CAST(Country AS STRING)                                             AS Country,
      CAST(0.0 AS DECIMAL(15,2))                                          AS `Country List Price`,
      CAST(0.0 AS DECIMAL(17,2))                                          AS `List Price`,
      CAST('' AS STRING)                                                  AS `Distributor Branch Key`,
      CAST('' AS STRING)                                                  AS `Distributor Number`,
      CAST('' AS STRING)                                                  AS `Reason Code`,
      CAST('' AS STRING)                                                  AS `Reason Code Description`,
      CAST('' AS STRING)                                                  AS `Settlement Number`,
      CAST(NULL AS DATE)                                                  AS `Settlement Date`,
      CAST('' AS STRING)                                                  AS `Reference Number`,
      CAST('' AS STRING)                                                  AS `Rebate Period`,
      CAST('' AS STRING)                                                  AS `Trade Org No`,
      CAST(0.0 AS DECIMAL(15,3))                                          AS `Quantity`,
      CAST(0.0 AS DECIMAL(15,2))                                          AS `Settlement Amount`,
      CAST('' AS STRING)                                                  AS `Reference Item`,
      CAST('' AS STRING)                                                  AS `Settlement Status Item`,
      CAST('' AS STRING)                                                  AS `Debit Credit Indicator`,
      CAST('' AS STRING)                                                  AS `Header Settlement Status`,
      CAST(NULL AS DATE)                                                  AS `Billing Date`,
      CAST(0.0 AS DECIMAL(15,2))                                          AS `Dealer Submitted Cost`,
      CAST(0.0 AS DECIMAL(11,2))                                          AS `Net Price`,
      CAST(0 AS INT)                                                      AS `Numerator`,
      CAST(0 AS INT)                                                      AS `Denominator`,
      CAST(NULL AS DATE)                                                  AS `Last Settlement Date`,
      CAST(NULL AS DATE)                                                  AS `Tracings Approval Date`,
      CAST('' AS STRING)                                                  AS `Agreement Determined`,
      CAST('' AS STRING)                                                  AS `Deletion Indicator Header`,
      CAST('' AS STRING)                                                  AS `Deletion Indicator Item`,
      CAST('' AS STRING)                                                  AS `Translated Agreement`,
      CAST('' AS STRING)                                                  AS `Tolerance Indicator`,
      CAST('' AS STRING)                                                  AS `Rebate Payment Type`,
      CAST(NULL AS DATE)                                                  AS `Claim Item Batch Creation Date`,
      CAST('' AS STRING)                                                  AS `Period Close Indicator`,
      CAST(NULL AS DATE)                                                  AS `Created On Header`,
      CAST(NULL AS DATE)                                                  AS `Created On Item`,
      CAST('' AS STRING)                                                  AS `Condition Document Number`,
      CAST('' AS STRING)                                                  AS `Changed By Item`,
      CAST('' AS STRING)                                                  AS `Changed On Item`,
      CAST('' AS STRING)                                                  AS `Material Description Japanese`,
      CAST('' AS STRING)                                                  AS `Distributor End Customer No`,
      CAST(TerritoryKey AS STRING)                                        AS `Territory Key`,
      CAST(JdeMaterialCategoryKey AS STRING)                              AS `Jde Material Category Key`,
      CAST(MaterialCostKey AS STRING)                                     AS `Material Cost Key`,
      CAST(BudgetKey AS STRING)                                           AS `Budget Key`,
      CAST('' AS STRING)                                                  AS `Ship To Po`,
      CAST(Year AS INT)                                                   AS Year,
      CAST(Month AS INT)                                                  AS Month,
      CAST('' AS STRING)                                                  AS Wwb,
      CAST('' AS STRING)                                                  AS `Strategy Center`,
      CAST('' AS STRING)                                                  AS `Lot No`,
      CAST(RebateCode AS STRING)                                          AS `Rebate Code`,
      CAST('' AS STRING)                                                  AS `Business Partner Area`,
      CAST('' AS STRING)                                                  AS `Accounting Document`,
      CAST('' AS STRING)                                                  AS `Reference Document`,
      CAST('' AS STRING)                                                  AS `Customer Material`,
      CAST('' AS STRING)                                                  AS `Customer Material Description`,
      CAST(Batch AS STRING)                                               AS Batch,
      CAST(RequestedDeliveryDate AS DATE)                                 AS `Requested Delivery Date`,
      CAST(SalesOrderDate AS DATE)                                        AS `Sales Order Date`,
      CAST(cal.FirstDateOfMonth AS DATE)                                  AS `First Date Of Month`,
      CAST(dsj.DateAdded AS TIMESTAMP)                                    AS `Date Added`
  FROM hub_prd.s_commops_ga.direct_sales_jde dsj
  LEFT JOIN hub_prd.s_shared.calendar_periods_ga cal
    ON cal.CalendarDate = CAST(dsj.InvoiceDate AS DATE)

  UNION ALL

  -- =========================
  -- Traced (traced_sales_everest)
  -- =========================
  SELECT
      CAST(BillingSourceSystem AS STRING)                                 AS `Billing Source System`,
      CAST(SourceSystemId AS STRING)                                       AS `Source System Id`,
      CAST(MaterialId AS STRING)                                           AS `Material Id`,
      CAST(MaterialKey AS STRING)                                          AS `Material Key`,
      CAST(BillMasterKey AS STRING)                                        AS `Bill Master Key`,
      CAST(ErpCustomerKey AS STRING)                                       AS `Erp Customer Key`,
      CAST(DistributorKey AS STRING)                                       AS `Distributor Key`,
      CAST(CustomerMasterSalesKey AS STRING)                               AS `Customer Master Sales Key`,
      CAST(AgreementKey AS STRING)                                         AS `Agreement Key`,
      CAST(InvoiceDate AS DATE)                                            AS `Invoice Date`,
      CAST(DocumentId AS STRING)                                           AS `Document Id`,
      CAST(DocumentIdItem AS STRING)                                       AS `Document Id Item`,
      CAST(InvoiceNumber AS STRING)                                        AS `Invoice Number`,
      CAST(InvoiceLineItem AS STRING)                                      AS `Invoice Line Item`,
      CAST(BillingType AS STRING)                                          AS `Billing Type`,
      CAST(BillingTypeDescription AS STRING)                               AS `Billing Type Description`,
      CAST(SalesOrder AS STRING)                                           AS `Sales Order`,
      CAST(SalesOrderItem AS STRING)                                       AS `Sales Order Item`,
      CAST(SalesItemCategory AS STRING)                                    AS `Sales Item Category`,
      CAST(BaseUom AS STRING)                                              AS `Base Uom`,
      CAST(SalesUom AS STRING)                                             AS `Sales Uom`,
      CAST(BillingQuantity AS DECIMAL(15,3))                               AS `Billing Quantity`,
      CAST(BillQtyInEa AS DECIMAL(23,4))                                   AS `Billing Quantity in EA`,
      CAST(InvoiceQuantity AS DECIMAL(13,3))                               AS `Invoice Quantity`,
      CAST(LocalCurrency AS STRING)                                        AS `Local Currency`,
      CAST(ActualNetRevenue AS DECIMAL(25,2))                              AS `Actual Net Revenue`,
      CAST(SalesOrgId AS STRING)                                           AS `Sales Org Id`,
      CAST('' AS STRING)                                                   AS `Sales Org Description`,
      CAST(DistributionChannel AS STRING)                                  AS `Distribution Channel`,
      CAST(DistributionChannelDescription AS STRING)                       AS `Distribution Channel Description`,
      CAST(Division AS STRING)                                             AS Division,
      CAST('' AS STRING)                                                   AS `Division Description`,
      CAST('' AS STRING)                                                   AS `Profit Center Id`,
      CAST('' AS STRING)                                                   AS `Profit Center Description`,
      CAST(Plant AS STRING)                                                AS Plant,
      CAST(PlantDescription AS STRING)                                     AS `Plant Description`,
      CAST(0.0 AS DECIMAL(13,2))                                           AS `Gross Sales`,
      CAST(0.0 AS DECIMAL(23,2))                                           AS `Gross Revenue`,
      CAST(0.0 AS DECIMAL(13,2))                                           AS `Discounted Net Value`,
      CAST(0.0 AS DECIMAL(13,2))                                           AS `Discounted Net Value Adjusted`,
      CAST(0.0 AS DECIMAL(13,2))                                           AS `Shipping Handling Freight Surcharge`,
      CAST(0.0 AS DECIMAL(13,2))                                           AS Adjustments,
      CAST(0.0 AS DECIMAL(13,2))                                           AS `Sales Tax`,
      CAST('' AS STRING)                                                   AS `Customer Po Number`,
      CAST('' AS STRING)                                                   AS `Condition Pricing Unit`,
      CAST(PricingDate AS DATE)                                            AS `Pricing Date`,
      CAST(ProductHierarchy AS STRING)                                     AS `Product Hierarchy`,
      CAST(DirectSalesViewFlag AS STRING)                                  AS `Direct Sales View Flag`,
      CAST(CustomerViewFlag AS STRING)                                     AS `Customer View Flag`,
      CAST(SalesFlag AS STRING)                                            AS `Sales Flag`,
      CAST(UnsettledTracingFlag AS STRING)                                 AS `Unsettled Tracing Flag`,
      CAST(RecipientId AS STRING)                                          AS `Recipient Id`,
      CAST(RecipientRole AS STRING)                                        AS `Recipient Role`,
      CAST(SalesDataType AS STRING)                                        AS `Sales Data Type`,
      CAST(Payer AS STRING)                                                AS Payer,
      CAST(SalesDocumentType AS STRING)                                    AS `Sales Document Type`,
      CAST('' AS STRING)                                                   AS `Sales Document Type Description`,
      CAST(RecordIndicator AS STRING)                                      AS `Record Indicator`,
      CAST(ContractAtTimeOfSale AS STRING)                                 AS `Contract At Time Of Sale`,
      CAST(IndirectSellDate AS DATE)                                       AS `Indirect Sell Date`,
      CAST(TransactionType AS STRING)                                      AS `Transaction Type`,
      CAST(SalesPackageQuantity AS INT)                                    AS `Sales Package Quantity`,
      CAST(LineCost AS DECIMAL(38,6))                                      AS `Line Cost`,
      CAST(ActualGrossProfit AS STRING)                                    AS `Actual Gross Profit`,
      CAST(ShipToAccountNumber AS STRING)                                  AS `Ship To Account Number`,
      CAST(BillToAccountNumber AS STRING)                                  AS `Bill To Account Number`,
      CAST(SoldToAccountNumber AS STRING)                                  AS `Sold To Account Number`,
      CAST(UnitSellingPrice AS DECIMAL(36,11))                             AS `Unit Selling Price`,
      CAST(RebateAccrual AS DECIMAL(15,2))                                 AS `Rebate Accrual`,
      CAST(ActualRebateAmount AS DECIMAL(15,2))                            AS `Actual Rebate Amount`,
      CAST(GpoAtTimeOfSale AS STRING)                                      AS `Gpo At Time Of Sale`,
      CAST(BrokeragePercentage AS DECIMAL(11,2))                           AS `Brokerage Percentage`,
      CAST(TradeOrgAtTimeOfSale AS STRING)                                 AS `Trade Org At Time Of Sale`,
      CAST(Country AS STRING)                                              AS Country,
      CAST(CountryListPrice AS DECIMAL(15,2))                              AS `Country List Price`,
      CAST(ListPrice AS DECIMAL(17,2))                                     AS `List Price`,
      CAST(DistributorBranchKey AS STRING)                                 AS `Distributor Branch Key`,
      CAST(DistributorNumber AS STRING)                                    AS `Distributor Number`,
      CAST(ReasonCode AS STRING)                                           AS `Reason Code`,
      CAST(ReasonCodeDescription AS STRING)                                AS `Reason Code Description`,
      CAST(SettlementNumber AS STRING)                                     AS `Settlement Number`,
      CAST(SettlementDate AS DATE)                                         AS `Settlement Date`,
      CAST(ReferenceNumber AS STRING)                                      AS `Reference Number`,
      CAST(RebatePeriod AS STRING)                                         AS `Rebate Period`,
      CAST(TradeOrgNo AS STRING)                                           AS `Trade Org No`,
      CAST(Quantity AS DECIMAL(15,3))                                      AS `Quantity`,
      CAST(SettlementAmount AS DECIMAL(15,2))                              AS `Settlement Amount`,
      CAST(ReferenceItem AS STRING)                                        AS `Reference Item`,
      CAST(SettlementStatusItem AS STRING)                                 AS `Settlement Status Item`,
      CAST(DebitCreditIndicator AS STRING)                                 AS `Debit Credit Indicator`,
      CAST(HeaderSettlementStatus AS STRING)                               AS `Header Settlement Status`,
      CAST(BillingDate AS DATE)                                            AS `Billing Date`,
      CAST(DealerSubmittedCost AS DECIMAL(15,2))                           AS `Dealer Submitted Cost`,
      CAST(NetPrice AS DECIMAL(11,2))                                      AS `Net Price`,
      CAST(Numerator AS INT)                                               AS `Numerator`,
      CAST(Denominator AS INT)                                             AS `Denominator`,
      CAST(LastSettlementDate AS DATE)                                     AS `Last Settlement Date`,
      CAST(TracingsApprovalDate AS DATE)                                   AS `Tracings Approval Date`,
      CAST(AgreementDetermined AS STRING)                                  AS `Agreement Determined`,
      CAST(DeletionIndicatorHeader AS STRING)                              AS `Deletion Indicator Header`,
      CAST(DeletionIndicatorItem AS STRING)                                AS `Deletion Indicator Item`,
      CAST(TranslatedAgreement AS STRING)                                  AS `Translated Agreement`,
      CAST(ToleranceIndicator AS STRING)                                   AS `Tolerance Indicator`,
      CAST(RebatePaymentType AS STRING)                                    AS `Rebate Payment Type`,
      CAST(ClaimItemBatchCreationDate AS DATE)                             AS `Claim Item Batch Creation Date`,
      CAST(PeriodCloseIndicator AS STRING)                                 AS `Period Close Indicator`,
      CAST(CreatedOnHeader AS DATE)                                        AS `Created On Header`,
      CAST(CreatedOnItem AS DATE)                                          AS `Created On Item`,
      CAST(ConditionDocumentNumber AS STRING)                              AS `Condition Document Number`,
      CAST(ChangedByItem AS STRING)                                        AS `Changed By Item`,
      CAST(ChangedOnItem AS STRING)                                        AS `Changed On Item`,
      CAST(MaterialDescriptionJapanese AS STRING)                          AS `Material Description Japanese`,
      CAST(DistributorEndCustomerNo AS STRING)                             AS `Distributor End Customer No`,
      CAST('' AS STRING)                                                  AS `Territory Key`,
      CAST('' AS STRING)                                                  AS `Jde Material Category Key`,
      CAST('' AS STRING)                                                  AS `Material Cost Key`,
      CAST('' AS STRING)                                                  AS `Budget Key`,
      CAST('' AS STRING)                                                  AS `Ship To Po`,
      CAST(NULL AS INT)                                                   AS Year,
      CAST(NULL AS INT)                                                   AS Month,
      CAST('' AS STRING)                                                  AS Wwb,
      CAST('' AS STRING)                                                  AS `Strategy Center`,
      CAST('' AS STRING)                                                  AS `Lot No`,
      CAST('' AS STRING)                                                  AS `Rebate Code`,
      CAST('' AS STRING)                                                  AS `Business Partner Area`,
      CAST('' AS STRING)                                                  AS `Accounting Document`,
      CAST('' AS STRING)                                                  AS `Reference Document`,
      CAST('' AS STRING)                                                  AS `Customer Material`,
      CAST('' AS STRING)                                                  AS `Customer Material Description`,
      CAST('' AS STRING)                                                  AS `Batch`,
      CAST(NULL AS DATE)                                                  AS `Requested Delivery Date`,
      CAST(NULL AS DATE)                                                  AS `Sales Order Date`,
      CAST(cal.FirstDateOfMonth AS DATE)                                   AS `First Date Of Month`,
      CAST(tse.DateAdded AS TIMESTAMP)                                     AS `Date Added`
  FROM hub_prd.s_commops_ga.traced_sales_everest tse
  LEFT JOIN hub_prd.s_shared.calendar_periods_ga cal
    ON cal.CalendarDate = CAST(tse.InvoiceDate AS DATE)
),
b AS (
  SELECT u.*
  FROM base u
  INNER JOIN hub_prd.s_commops_ga.unified_material_master_ga m
    ON u.`Material Key` = m.MaterialKey
  WHERE m.ReltioPHLevel1 IN (
    'Alaris System','Hazardous Drug Solutions','IV Solutions',
    'Gravity and Syringe Delivery','IV Access','CME','Alaris Plus',
    'IPD OEM','BD Nexus'
  )
)
SELECT
  `Billing Source System`             AS BillingSourceSystem,
  `Source System Id`                  AS SourceSystemId,
  `Material Id`                       AS MaterialId,
  `Material Key`                      AS MaterialKey,
  `Bill Master Key`                   AS BillMasterKey,
  `Erp Customer Key`                  AS ErpCustomerKey,
  `Distributor Key`                   AS DistributorKey,
  `Customer Master Sales Key`         AS CustomerMasterSalesKey,
  `Agreement Key`                     AS AgreementKey,
  `Invoice Date`                      AS InvoiceDate,
  `Document Id`                       AS DocumentId,
  `Document Id Item`                  AS DocumentIdItem,
  `Invoice Number`                    AS InvoiceNumber,
  `Invoice Line Item`                 AS InvoiceLineItem,
  `Billing Type`                      AS BillingType,
  `Billing Type Description`          AS BillingTypeDescription,
  `Sales Order`                       AS SalesOrder,
  `Sales Order Item`                  AS SalesOrderItem,
  `Sales Item Category`               AS SalesItemCategory,
  `Base Uom`                          AS BaseUOM,
  `Sales Uom`                         AS SalesUOM,
  `Billing Quantity`                  AS BillingQuantity,
  `Billing Quantity in EA`            AS BillingQuantityInEA,
  `Invoice Quantity`                  AS InvoiceQuantity,
  `Local Currency`                    AS LocalCurrency,
  `Actual Net Revenue`                AS ActualNetRevenue,
  `Sales Org Id`                      AS SalesOrgId,
  `Sales Org Description`             AS SalesOrgDescription,
  `Distribution Channel`              AS DistributionChannel,
  `Distribution Channel Description`  AS DistributionChannelDescription,
  Division                            AS Division,
  `Division Description`              AS DivisionDescription,
  `Profit Center Id`                  AS ProfitCenterId,
  `Profit Center Description`         AS ProfitCenterDescription,
  Plant                               AS Plant,
  `Plant Description`                 AS PlantDescription,
  `Gross Sales`                       AS GrossSales,
  `Gross Revenue`                     AS GrossRevenue,
  `Discounted Net Value`              AS DiscountedNetValue,
  `Discounted Net Value Adjusted`     AS DiscountedNetValueAdjusted,
  `Shipping Handling Freight Surcharge` AS ShippingHandlingFreightSurcharge,
  Adjustments                         AS Adjustments,
  `Sales Tax`                         AS SalesTax,
  `Customer Po Number`                AS CustomerPONumber,
  `Condition Pricing Unit`            AS ConditionPricingUnit,
  `Pricing Date`                      AS PricingDate,
  `Product Hierarchy`                 AS ProductHierarchy,
  `Direct Sales View Flag`            AS DirectSalesViewFlag,
  `Customer View Flag`                AS CustomerViewFlag,
  `Sales Flag`                        AS SalesFlag,
  `Unsettled Tracing Flag`            AS UnsettledTracingFlag,
  `Recipient Id`                      AS RecipientId,
  `Recipient Role`                    AS RecipientRole,
  `Sales Data Type`                   AS SalesDataType,
  Payer                               AS Payer,
  `Sales Document Type`               AS SalesDocumentType,
  `Sales Document Type Description`   AS SalesDocumentTypeDescription,
  `Record Indicator`                  AS RecordIndicator,
  `Contract At Time Of Sale`          AS ContractAtTimeOfSale,
  `Indirect Sell Date`                AS IndirectSellDate,
  `Transaction Type`                  AS TransactionType,
  `Sales Package Quantity`            AS SalesPackageQuantity,
  `Line Cost`                         AS LineCost,
  `Actual Gross Profit`               AS ActualGrossProfit,
  `Ship To Account Number`            AS ShipToAccountNumber,
  `Bill To Account Number`            AS BillToAccountNumber,
  `Sold To Account Number`            AS SoldToAccountNumber,
  `Unit Selling Price`                AS UnitSellingPrice,
  `Rebate Accrual`                    AS RebateAccrual,
  `Actual Rebate Amount`              AS ActualRebateAmount,
  `Gpo At Time Of Sale`               AS GpoAtTimeOfSale,
  `Brokerage Percentage`              AS BrokeragePercentage,
  `Trade Org At Time Of Sale`         AS TradeOrgAtTimeOfSale,
  Country                             AS Country,
  `Country List Price`                AS CountryListPrice,
  `List Price`                        AS ListPrice,
  `Distributor Branch Key`            AS DistributorBranchKey,
  `Distributor Number`                AS DistributorNumber,
  `Reason Code`                       AS ReasonCode,
  `Reason Code Description`           AS ReasonCodeDescription,
  `Settlement Number`                 AS SettlementNumber,
  `Settlement Date`                   AS SettlementDate,
  `Reference Number`                  AS ReferenceNumber,
  `Rebate Period`                     AS RebatePeriod,
  `Trade Org No`                      AS TradeOrgNo,
  Quantity                            AS Quantity,
  `Settlement Amount`                 AS SettlementAmount,
  `Reference Item`                    AS ReferenceItem,
  `Settlement Status Item`            AS SettlementStatusItem,
  `Debit Credit Indicator`            AS DebitCreditIndicator,
  `Header Settlement Status`          AS HeaderSettlementStatus,
  `Billing Date`                      AS BillingDate,
  `Dealer Submitted Cost`             AS DealerSubmittedCost,
  `Net Price`                         AS NetPrice,
  Numerator                           AS Numerator,
  Denominator                         AS Denominator,
  `Last Settlement Date`              AS LastSettlementDate,
  `Tracings Approval Date`            AS TracingsApprovalDate,
  `Agreement Determined`              AS AgreementDetermined,
  `Deletion Indicator Header`         AS DeletionIndicatorHeader,
  `Deletion Indicator Item`           AS DeletionIndicatorItem,
  `Translated Agreement`              AS TranslatedAgreement,
  `Tolerance Indicator`               AS ToleranceIndicator,
  `Rebate Payment Type`               AS RebatePaymentType,
  `Claim Item Batch Creation Date`    AS ClaimItemBatchCreationDate,
  `Period Close Indicator`            AS PeriodCloseIndicator,
  `Created On Header`                 AS CreatedOnHeader,
  `Created On Item`                   AS CreatedOnItem,
  `Condition Document Number`         AS ConditionDocumentNumber,
  `Changed By Item`                   AS ChangedByItem,
  `Changed On Item`                   AS ChangedOnItem,
  `Material Description Japanese`     AS MaterialDescriptionJapanese,
  `Distributor End Customer No`       AS DistributorEndCustomerNo,
  `Territory Key`                     AS TerritoryKey,
  `Jde Material Category Key`         AS JdeMaterialCategoryKey,
  `Material Cost Key`                 AS MaterialCostKey,
  `Budget Key`                        AS BudgetKey,
  `Ship To Po`                        AS ShipToPo,
  Year                                AS Year,
  Month                               AS Month,
  Wwb                                 AS Wwb,
  `Strategy Center`                   AS StrategyCenter,
  `Lot No`                            AS LotNo,
  `Rebate Code`                       AS RebateCode,
  `Business Partner Area`             AS BusinessPartnerArea,
  `Accounting Document`               AS AccountingDocument,
  `Reference Document`                AS ReferenceDocument,
  `Customer Material`                 AS CustomerMaterial,
  `Customer Material Description`     AS CustomerMaterialDescription,
  Batch                               AS Batch,
  `Requested Delivery Date`           AS RequestedDeliveryDate,
  `Sales Order Date`                  AS SalesOrderDate,
  `First Date Of Month`               AS FirstDateOfMonth,
  `Date Added`                        AS DateAdded
FROM b;
