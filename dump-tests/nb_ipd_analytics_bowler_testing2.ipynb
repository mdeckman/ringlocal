# %% [markdown]
# I need all of the billing
# I need all of the orders
# I need finance
#
# Helper =
# Reltio for product via material key
# Date will likely do in power bi
# Geographies TBD where i pull it from

# %% [markdown]
# Testing all of the billing master columns - US, CA, LATAM, GA
# For EMEA we will pull from the dataflow for now

# %% [markdown]
# Greater Asia Billing

# %%
display(spark.table("hub_prd.g_commops_ga.v_billing_master").schema.names)

# %%
display(spark.table("hub_prd.g_commops_ga.v_billing_master"))

# %%
# _1
# Billing Source System
# Source System Id
# Material Id
    # Material Key
# Bill Master Key
# Erp Customer Key
# Distributor Key
# Customer Master Sales Key
# Agreement Key
    # Invoice Date
# Document Id
# Document Id Item
# Invoice Number
# Invoice Line Item
# Billing Type
# Billing Type Description
# Sales Order
# Sales Order Item
# Sales Item Category
# Base Uom
# Sales Uom
    # Billing Quantity
    # Billing Quantity in EA
    # Invoice Quantity
    # Local Currency
    # Actual Net Revenue
# Sales Org Id
# Sales Org Description
# Distribution Channel
    # Distribution Channel Description
# Division
# Division Description
# Profit Center Id
# Profit Center Description
# Plant
# Plant Description
    # Gross Sales
    # Gross Revenue
    # Discounted Net Value
    # Discounted Net Value Adjusted
# Shipping Handling Freight Surcharge
# Adjustments
# Sales Tax
    # Customer Po Number
# Condition Pricing Unit
# Pricing Date
# Product Hierarchy
# Direct Sales View Flag
# Customer View Flag
    # Sales Flag
# Unsettled Tracing Flag
# Recipient Id
# Recipient Role
# Sales Data Type
# Payer
# Sales Document Type
# Sales Document Type Description
    # Record Indicator
# Contract At Time Of Sale
    # Indirect Sell Date
    # Transaction Type
# Sales Package Quantity
# Line Cost
# Actual Gross Profit
    # Ship To Account Number
    # Bill To Account Number
    # Sold To Account Number
    # Unit Selling Price
# Rebate Accrual
# Actual Rebate Amount
# Gpo At Time Of Sale
# Brokerage Percentage
# Trade Org At Time Of Sale
# Country
# Country List Price
# List Price
# Distributor Branch Key
# Distributor Number
# Reason Code
# Reason Code Description
# Settlement Number
# Settlement Date
# Reference Number
# Rebate Period
# Trade Org No
    # Quantity
# Settlement Amount
# Reference Item
# Settlement Status Item
# Debit Credit Indicator
# Header Settlement Status
    # Billing Date
# Dealer Submitted Cost
# Net Price
# Numerator
# Denominator
# Last Settlement Date
# Tracings Approval Date
# Agreement Determined
# Deletion Indicator Header
# Deletion Indicator Item
# Translated Agreement
# Tolerance Indicator
# Rebate Payment Type
# Claim Item Batch Creation Date
# Period Close Indicator
# Created On Header
# Created On Item
# Condition Document Number
# Changed By Item
# Changed On Item
# Material Description Japanese
# Distributor End Customer No
# Territory Key
# Jde Material Category Key
# Material Cost Key
# Budget Key
# Ship To Po
# Year
# Month
# Wwb
# Strategy Center
# Lot No
# Rebate Code
# Business Partner Area
# Accounting Document
# Reference Document
# Customer Material
# Customer Material Description
# Batch
    # Requested Delivery Date
    # Sales Order Date
# First Date Of Month
# Date Added

# %% [markdown]
# US Billing

# %%
display(spark.table("hub_prd.s_commops_na.billing_master_us"))

# %%
# columns inbilling master
# _1
# Bill Master Key
# CSM Bill Key
    # ERP Customer Key
    # Material Key
    # Agreement Key
    # Customer Master Sales Key
    # Distributor Key
# Distributor Branch Key
# Customer Material Direct Flag Key
# Direct Sales View Flag
# Customer View Flag
# Commissionable View Flag
# Marketing View Flag
# Sales Flag
# Billing Source System
# Source System ID
    # Invoice Date
    # Indirect Sell Date
    # Reporting Date
# Rebate Claim Date
# Pricing Date
# Invoice Number
# Invoice Line Item
# Billing Type
    # Billing Type Description
    # Sales Order
# Sales Order Item
# Sales Document Type
# Sales Item Category
    # Transaction Type
# Record Indicator
# Revenue Type
# Base UoM
# Sales UoM
    # Invoice Quantity
    # Billing Quantity
# Bill Qty In Ea
# Local Currency
    # Actual Net Revenue
# Commissionable Net Revenue
    # Gross Sales
# Actual Gross Profit
# Commissionable Gross Profit
# Freight Charges
# Rebate Accrual
# Actual Rebate Amount
# Line Cost
# Unit Selling Price
# Distributor List Price Flag
# Brokerage
# Brokerage Percentage
# Condition Pricing Unit
# Customer PO#
# Sales Org ID
# Sales Org Description
# Profit Center ID
# Profit Center Description
    # Ship To Account#
    # Bill To Account#
    # Sold To Account#
    # Distributor#
    # Distribution Channel
# Division
# Legacy Customer#
# Legacy Business
# Plant
# Plant Description
# Billing Material Description
    # Contract At Time Of Sale
    # GPO At Time Of Sale
# Trade Org At Time Of Sale
# Country
    # On Invoice Discount
    # Date Invoiced On
# Date Added
# Partition Date
# Updated Date
# Table Partition Value

# %% [markdown]
# Billing latam

# %%
display(spark.table("hub_prd.s_region_latam.billing_master_latam").schema.names)

# %%
display(spark.table("hub_prd.s_region_latam.billing_master_latam"))

# %%
# %md
# _1
# InfoSource
# SourceSystemId
  # BillMasterKey
  # BillOrderKey
# InvoiceNumber
# InvoiceLineItem
  # SoldToAccountNumber
  # ShipToAccountNumber
# Country
# SalesOrgId
  # BillingType
# CustomerGroup3
  # MaterialId
# Plant
# LocalCurrency
# SalesItemCategory
  # InvoiceDate
  # DeferredDate
# Cancelled
# CancelledInvoiceDocumentNumber
# ReferenceDocumentNumber
# HeaderReferenceDocumentNumber
  # OrderType
# CreditDebitReasonCode
# CreditDebitReasonDescription
  # BillingQuantity
  # BillingQtyFreeofCharge
  # ActualNetRevenue
  # ActualNetRevenueUsd
# TaxAmount
# TaxAmountUsd
# GrossSales
# GrossSalesUsd
# UnitPrice
# UnitPriceUsd
# ActualRebateAmount
# ActualRebateAmountUsd
# DiscountAmount
# DiscountAmountUsd
# PerformanceBudget
# PerformanceForcast
# PerformancePrior
# ActualBudgetForecastFlag
# FreeOfChargeFlag
# PricingMapFlag
# DistributionChannel
  # DateAdded

# %% [markdown]
# Canada Billing

# %%
display(spark.table("hub_prd.g_commops_na.v_billing_master_ca").schema.names)

# %% [markdown]
# Same as the US - can use same logic

# %% [markdown]
# Now testing the finance dataproduct
# we need actuals - should be similar to billing
# we need budget
# we need projection which should have planning
#
# I think we can pull all tables filtered on IPD
# and then just link out on the keys for product and countries - no transformation need

# %%
df = spark.table("hub_prd.g_bpc_finance.v_revenue_actual_mds_mms")
display(df)
display(df.schema.names)

# %%
# %md
# _1
# ReltioBU
# Source
# RptCurrency
# RPTCurrency_Key
# Currency
  # FICountry - this is the country code from finance likely to be linked with v_country global
# Country
# CompCode
# LegacyProfitCenter
# SoldtoCustomer
# GLAccount
# GLRptCatg
# GLRptAcct
# ReltioGLAcct
# ReltioProfitCtr
# UOM
# ReltioMaterial
# MaterialID
# SalesChannel
  # Reltio_Internal_ID   - this is the product key
# FiscalYearPeriod
# ActRevenue
# ActRevProjRate
# ActRevPRJ1Rate
# ActRevPRJ2Rate
# ActRevPRJ3Rate
# ActRevBUDRate
# ActRevPYRate
# ActRevFXImpvsProj
# ActRevFXImpvsBudget
# ActRevFXImpvsPY
# ActUnits
# ActCost
# ActCOSProjRate
# ActCostPRJ1Rate
# ActCostPRJ2Rate
# ActCostPRJ3Rate
# ActCOSBUDRate
# ActCOSPYRate
# ActCOSFXImpvsProj
# ActCOSFXImpvsBudget
# ActCOSFXImpvsPY
# ActRevProjAdj
# ActRevBudAdj
# ActRevPYAdj
# ActCOSProjAdj
# ActCOSBudAdj
# ActCOSPYAdj
# OriginalSoldtoCustomer
# CalenderYearMonth

# %% [markdown]
# reltio internal ID = material key - needs to be broken into two piece

# %%
df = spark.table("hub_prd.g_bpc_finance.v_revenue_budget_mds_mms")
display(df)
display(df.schema.names)
